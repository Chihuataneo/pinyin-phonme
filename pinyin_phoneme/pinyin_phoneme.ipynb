# %%
import numpy as np
import pandas as pd

# %%
#把一个拼音和音素对应的DataFrame赋值给df
df = pd.DataFrame({'pinyin' : ["a","ai","an","ang","ao","ba","bai","ban","bang","bao","bei","ben","beng","bi","bian","biao","bie","bin","bing","bo","bu","ca","cai","can","cang","cao","ce","cen","ceng","cha","chai","chan","chang","chao","che","chen","cheng","chi","chong","chou","chu","chua","chuai","chuan","chuang","chui","chun","chuo","ci","cong","cou","cu","cuan","cui","cun","cuo","da","dai","dan","dang","dao","de","den","dei","deng","di","dia","dian","diao","die","ding","diu","dong","dou","du","duan","dui","dun","duo","e","ei","en","eng","er","fa","fan","fang","fei","fen","feng","fo","fou","fu","ga","gai","gan","gang","gao","ge","gei","gen","geng","gong","gou","gu","gua","guai","guan","guang","gui","gun","guo","ha","hai","han","hang","hao","he","hei","hen","heng","hong","hou","hu","hua","huai","huan","huang","hui","hun","huo","ji","jia","jian","jiang","jiao","jie","jin","jing","jiong","jiu","ju","juan","jue","jun","ka","kai","kan","kang","kao","ke","ken","keng","kong","kou","ku","kua","kuai","kuan","kuang","kui","kun","kuo","la","lai","lan","lang","lao","le","lei","leng","li","lia","lian","liang","liao","lie","lin","ling","liu","long","lou","lu","lv","luan","lue","lve","lun","luo","ma","mai","man","mang","mao","me","mei","men","meng","mi","mian","miao","mie","min","ming","miu","mo","mou","mu","na","nai","nan","nang","nao","ne","nei","nen","neng","ng","ni","nian","niang","niao","nie","nin","ning","niu","nong","nou","nu","nv","nuan","nve","nuo","nun","o","ou","pa","pai","pan","pang","pao","pei","pen","peng","pi","pian","piao","pie","pin","ping","po","pou","pu","qi","qia","qian","qiang","qiao","qie","qin","qing","qiong","qiu","qu","quan","que","qun","ran","rang","rao","re","ren","reng","ri","rong","rou","ru","ruan","rui","run","ruo","sa","sai","san","sang","sao","se","sen","seng","sha","shai","shan","shang","shao","she","shei","shen","sheng","shi","shou","shu","shua","shuai","shuan","shuang","shui","shun","shuo","si","song","sou","su","suan","sui","sun","suo","ta","tai","tan","tang","tao","te","teng","ti","tian","tiao","tie","ting","tong","tou","tu","tuan","tui","tun","tuo","wa","wai","wan","wang","wei","wen","weng","wo","wu","xi","xia","xian","xiang","xiao","xie","xin","xing","xiong","xiu","xu","xuan","xue","xun","ya","yan","yang","yao","ye","yi","yin","ying","yo","yong","you","yu","yuan","yue","yun","za","zai","zan","zang","zao","ze","zei","zen","zeng","zha","zhai","zhan","zhang","zhao","zhe","zhei","zhen","zheng","zhi","zhong","zhou","zhu","zhua","zhuai","zhuan","zhuang","zhui","zhun","zhuo","zi","zong","zou","zu","zuan","zui","zun","zuo"]})
df["phoneme"] = ["a" ,"a :\i" ,"a :n" ,"A N" ,"AU" ,"p a" ,"p a :\i" ,"p a :n" ,"p A N" ,"p AU" ,"p e :\i" ,"p @ :n" ,"p @ N" ,"p i" ,"p iE :n" ,"p iAU" ,"p ie" ,"p i :n" ,"p i N" ,"p uo" ,"p u" ,"tsh a" ,"tsh a :\i" ,"tsh a :n" ,"tsh A N" ,"tsh AU" ,"tsh 7" ,"tsh @ :n" ,"tsh @ N" ,"ts`h a" ,"ts`h a :\i" ,"ts`h a :n" ,"ts`h A N" ,"ts`h AU" ,"ts`h 7" ,"ts`h @ :n" ,"ts`h @ N" ,"ts`h i`" ,"ts`h U N" ,"ts`h @U" ,"ts`h u" ,"ts`h ua" ,"ts`h ua :\i" ,"ts`h ua :n" ,"ts`h uA N" ,"ts`h ue :\i" ,"ts`h u@ :n" ,"ts`h uo" ,"tsh i\\" ,"tsh U N" ,"tsh @U" ,"tsh u" ,"tsh ua :n" ,"tsh ue :\i" ,"tsh u@ :n" ,"tsh uo" ,"t a" ,"t a :\i" ,"t a :n" ,"t A N" ,"t AU" ,"t 7" ,"t @ :n" ,"t e :\i" ,"t @ N" ,"t i" ,"t ia" ,"t iE :n" ,"t iAU" ,"t ie" ,"t i N" ,"t i@U" ,"t U N" ,"t @U" ,"t u" ,"t ua :n" ,"t ue :\i" ,"t u@ :n" ,"t uo" ,"7" ,"e :\i" ,"@ :n" ,"@ N" ,"a r\`" ,"f a" ,"f a :n" ,"f A N" ,"f e :\i" ,"f @ :n" ,"f @ N" ,"f uo" ,"f @U" ,"f u" ,"k a" ,"k a :\i" ,"k a :n" ,"k A N" ,"k AU" ,"k 7" ,"k e :\i" ,"k @ :n" ,"k @ N" ,"k U N" ,"k @U" ,"k u" ,"k ua" ,"k ua :\i" ,"k ua :n" ,"k uA N" ,"k ue :\i" ,"k u@ :n" ,"k uo" ,"x a" ,"x a :\i" ,"x a :n" ,"x A N" ,"x AU" ,"x 7" ,"x e :\i" ,"x @ :n" ,"x @ N" ,"x U N" ,"x @U" ,"x u" ,"x ua" ,"x ua :\i" ,"x ua :n" ,"x uA N" ,"x ue :\i" ,"x u@ :n" ,"x uo" ,"ts\ i" ,"ts\ ia" ,"ts\ iE :n" ,"ts\ iA N" ,"ts\ iAU" ,"ts\ ie" ,"ts\ i :n" ,"ts\ i N" ,"ts\ iU N" ,"ts\ i@U" ,"ts\ y" ,"ts\ y{ :n" ,"ts\ yE" ,"ts\ yE :n" ,"kh a" ,"kh a :\i" ,"kh a :n" ,"kh A N" ,"kh AU" ,"kh 7" ,"kh @ :n" ,"kh @ N" ,"kh U N" ,"kh @U" ,"kh u" ,"kh ua" ,"kh ua :\i" ,"kh ua :n" ,"kh uA N" ,"kh ue :\i" ,"kh u@ :n" ,"kh uo" ,"l a" ,"l a :\i" ,"l a :n" ,"l A N" ,"l AU" ,"l 7" ,"l e :\i" ,"l @ N" ,"l i" ,"l ia" ,"l iE :n" ,"l iA N" ,"l iAU" ,"l ie" ,"l i :n" ,"l i N" ,"l i@U" ,"l U N" ,"l @U" ,"l u" ,"l y" ,"l ua :n" ,"l yE" ,"l yE" ,"l u@ :n" ,"l uo" ,"m a" ,"m a :\i" ,"m a :n" ,"m A N" ,"m AU" ,"m 7" ,"m e :\i" ,"m @ :n" ,"m @ N" ,"m i" ,"m iE :n","m iAU" ,"m ie" ,"m i :n" ,"m i N" ,"m i@U" ,"m uo" ,"m @U" ,"m u" ,"n a" ,"n a :\i" ,"n a :n" ,"n A N" ,"n AU" ,"n 7" ,"n e :\i" ,"n @ :n" ,"n @ N" ,"N" ,"n i" ,"n iE :n" ,"n iA N" ,"n iAU" ,"n ie" ,"n i :n" ,"n i N" ,"n i@U" ,"n U N" ,"n @U" ,"n u" ,"n y" ,"n ua :n" ,"n yE" ,"n uo" ,"n u@ :n" ,"o" ,"@U" ,"ph a" ,"ph a :\i" ,"ph a :n" ,"ph A N" ,"ph AU" ,"ph e :\i" ,"ph @ :n" ,"ph @ N" ,"ph i" ,"ph iE :n" ,"ph iAU" ,"ph ie" ,"ph i :n" ,"ph i N" ,"ph uo" ,"ph @U" ,"ph u" ,"ts\h i" ,"ts\h ia" ,"ts\h iE :n" ,"ts\h iA N" ,"ts\h iAU" ,"ts\h ie" ,"ts\h i :n" ,"ts\h i N" ,"ts\h iU N" ,"ts\h i@U" ,"ts\h y" ,"ts\h y{ :n" ,"ts\h yE" ,"ts\h yE :n" ,"z` a :n" ,"z` A N" ,"z` AU" ,"z` 7" ,"z` @ :n" ,"z` @ N" ,"z` i`" ,"z` U N" ,"z` @U" ,"z` u" ,"z` ua :n" ,"z` ue :\i" ,"z` u@ :n" ,"z` uo" ,"s a" ,"s a :\i" ,"s a :n" ,"s A N" ,"s AU" ,"s 7" ,"s @ :n" ,"s @ N" ,"s` a" ,"s` a :\i" ,"s` a :n" ,"s` A N" ,"s` AU" ,"s` 7" ,"s` e :\i" ,"s` @ :n" ,"s` @ N" ,"s` i`" ,"s` @U" ,"s` u" ,"s` ua" ,"s` ua :\i" ,"s` ua :n" ,"s` uA N" ,"s` ue :\i" ,"s` u@ :n" ,"s` uo" ,"s i\\" ,"s U N" ,"s @U" ,"s u" ,"s ua :n" ,"s ue :\i" ,"s u@ :n" ,"s uo" ,"th a" ,"th a :\i" ,"th a :n" ,"th A N" ,"th AU" ,"th 7" ,"th @ N" ,"th i" ,"th iE :n" ,"th iAU" ,"th ie" ,"th i N" ,"th U N" ,"th @U" ,"th u" ,"th ua :n" ,"th ue :\i" ,"th u@ :n" ,"th uo" ,"w ua" ,"w ua :\i" ,"w ua :n" ,"w uA N" ,"w ue :\i" ,"w u@ :n" ,"w u@ N" ,"w uo" ,"u" ,"s\ i" ,"s\ ia" ,"s\ iE :n" ,"s\ iA N" ,"s\ iAU" ,"s\ ie" ,"s\ i :n" ,"s\ i N" ,"s\ iU N" ,"s\ i@U" ,"s\ y" ,"s\ y{ :n" ,"s\ yE" ,"s\ yE :n" ,"j ia" ,"j iE :n" ,"j iA N" ,"j iAU" ,"j ie" ,"i" ,"j i :n" ,"j i N" ,"j iAU" ,"j iU N" ,"j i@U" ,"y" ,"j y{ :n" ,"j yE" ,"j yE :n" ,"ts a" ,"ts a :\i" ,"ts a :n" ,"ts A N" ,"ts AU" ,"ts 7" ,"ts e :\i" ,"ts @ :n" ,"ts @ N" ,"ts` a" ,"ts` a :\i" ,"ts` a :n" ,"ts` A N" ,"ts` AU" ,"ts` 7" ,"ts` e :\i" ,"ts` @ :n" ,"ts` @ N" ,"ts` i`" ,"ts` U N" ,"ts` @U" ,"ts` u" ,"ts` ua" ,"ts` ua :\i" ,"ts` ua :n" ,"ts` uA N" ,"ts` ue :\i" ,"ts` u@ :n" ,"ts` uo" ,"ts i\\" ,"ts U N" ,"ts @U" ,"ts u" ,"ts ua :n" ,"ts ue :\i" ,"ts u@ :n" ,"ts uo"]
df
# Out:
#      pinyin     phoneme
# 0         a           a
# 1        ai       a :\i
# 2        an        a :n
# 3       ang         A N
# 4        ao          AU
# 5        ba         p a
# 6       bai     p a :\i
# 7       ban      p a :n
# 8      bang       p A N
# 9       bao        p AU
# 10      bei     p e :\i
# 11      ben      p @ :n
# 12     beng       p @ N
# 13       bi         p i
# 14     bian     p iE :n
# 15     biao       p iAU
# 16      bie        p ie
# 17      bin      p i :n
# 18     bing       p i N
# 19       bo        p uo
# 20       bu         p u
# 21       ca       tsh a
# 22      cai   tsh a :\i
# 23      can    tsh a :n
# 24     cang     tsh A N
# 25      cao      tsh AU
# 26       ce       tsh 7
# 27      cen    tsh @ :n
# 28     ceng     tsh @ N
# 29      cha      ts`h a
# ..      ...         ...
# 380     zen     ts @ :n
# 381    zeng      ts @ N
# 382     zha       ts` a
# 383    zhai   ts` a :\i
# 384    zhan    ts` a :n
# 385   zhang     ts` A N
# ...

# %%
#创建一个音素list
phoneme_li = ["a" ,"a :\i" ,"a :n" ,"A N" ,"AU" ,"p a" ,"p a :\i" ,"p a :n" ,"p A N" ,"p AU" ,"p e :\i" ,"p @ :n" ,"p @ N" ,"p i" ,"p iE :n" ,"p iAU" ,"p ie" ,"p i :n" ,"p i N" ,"p uo" ,"p u" ,"tsh a" ,"tsh a :\i" ,"tsh a :n" ,"tsh A N" ,"tsh AU" ,"tsh 7" ,"tsh @ :n" ,"tsh @ N" ,"ts`h a" ,"ts`h a :\i" ,"ts`h a :n" ,"ts`h A N" ,"ts`h AU" ,"ts`h 7" ,"ts`h @ :n" ,"ts`h @ N" ,"ts`h i`" ,"ts`h U N" ,"ts`h @U" ,"ts`h u" ,"ts`h ua" ,"ts`h ua :\i" ,"ts`h ua :n" ,"ts`h uA N" ,"ts`h ue :\i" ,"ts`h u@ :n" ,"ts`h uo" ,"tsh i\\" ,"tsh U N" ,"tsh @U" ,"tsh u" ,"tsh ua :n" ,"tsh ue :\i" ,"tsh u@ :n" ,"tsh uo" ,"t a" ,"t a :\i" ,"t a :n" ,"t A N" ,"t AU" ,"t 7" ,"t @ :n" ,"t e :\i" ,"t @ N" ,"t i" ,"t ia" ,"t iE :n" ,"t iAU" ,"t ie" ,"t i N" ,"t i@U" ,"t U N" ,"t @U" ,"t u" ,"t ua :n" ,"t ue :\i" ,"t u@ :n" ,"t uo" ,"7" ,"e :\i" ,"@ :n" ,"@ N" ,"a r\`" ,"f a" ,"f a :n" ,"f A N" ,"f e :\i" ,"f @ :n" ,"f @ N" ,"f uo" ,"f @U" ,"f u" ,"k a" ,"k a :\i" ,"k a :n" ,"k A N" ,"k AU" ,"k 7" ,"k e :\i" ,"k @ :n" ,"k @ N" ,"k U N" ,"k @U" ,"k u" ,"k ua" ,"k ua :\i" ,"k ua :n" ,"k uA N" ,"k ue :\i" ,"k u@ :n" ,"k uo" ,"x a" ,"x a :\i" ,"x a :n" ,"x A N" ,"x AU" ,"x 7" ,"x e :\i" ,"x @ :n" ,"x @ N" ,"x U N" ,"x @U" ,"x u" ,"x ua" ,"x ua :\i" ,"x ua :n" ,"x uA N" ,"x ue :\i" ,"x u@ :n" ,"x uo" ,"ts\ i" ,"ts\ ia" ,"ts\ iE :n" ,"ts\ iA N" ,"ts\ iAU" ,"ts\ ie" ,"ts\ i :n" ,"ts\ i N" ,"ts\ iU N" ,"ts\ i@U" ,"ts\ y" ,"ts\ y{ :n" ,"ts\ yE" ,"ts\ yE :n" ,"kh a" ,"kh a :\i" ,"kh a :n" ,"kh A N" ,"kh AU" ,"kh 7" ,"kh @ :n" ,"kh @ N" ,"kh U N" ,"kh @U" ,"kh u" ,"kh ua" ,"kh ua :\i" ,"kh ua :n" ,"kh uA N" ,"kh ue :\i" ,"kh u@ :n" ,"kh uo" ,"l a" ,"l a :\i" ,"l a :n" ,"l A N" ,"l AU" ,"l 7" ,"l e :\i" ,"l @ N" ,"l i" ,"l ia" ,"l iE :n" ,"l iA N" ,"l iAU" ,"l ie" ,"l i :n" ,"l i N" ,"l i@U" ,"l U N" ,"l @U" ,"l u" ,"l y" ,"l ua :n" ,"l yE" ,"l yE" ,"l u@ :n" ,"l uo" ,"m a" ,"m a :\i" ,"m a :n" ,"m A N" ,"m AU" ,"m 7" ,"m e :\i" ,"m @ :n" ,"m @ N" ,"m i" ,"m iE :n","m iAU" ,"m ie" ,"m i :n" ,"m i N" ,"m i@U" ,"m uo" ,"m @U" ,"m u" ,"n a" ,"n a :\i" ,"n a :n" ,"n A N" ,"n AU" ,"n 7" ,"n e :\i" ,"n @ :n" ,"n @ N" ,"N" ,"n i" ,"n iE :n" ,"n iA N" ,"n iAU" ,"n ie" ,"n i :n" ,"n i N" ,"n i@U" ,"n U N" ,"n @U" ,"n u" ,"n y" ,"n ua :n" ,"n yE" ,"n uo" ,"n u@ :n" ,"o" ,"@U" ,"ph a" ,"ph a :\i" ,"ph a :n" ,"ph A N" ,"ph AU" ,"ph e :\i" ,"ph @ :n" ,"ph @ N" ,"ph i" ,"ph iE :n" ,"ph iAU" ,"ph ie" ,"ph i :n" ,"ph i N" ,"ph uo" ,"ph @U" ,"ph u" ,"ts\h i" ,"ts\h ia" ,"ts\h iE :n" ,"ts\h iA N" ,"ts\h iAU" ,"ts\h ie" ,"ts\h i :n" ,"ts\h i N" ,"ts\h iU N" ,"ts\h i@U" ,"ts\h y" ,"ts\h y{ :n" ,"ts\h yE" ,"ts\h yE :n" ,"z` a :n" ,"z` A N" ,"z` AU" ,"z` 7" ,"z` @ :n" ,"z` @ N" ,"z` i`" ,"z` U N" ,"z` @U" ,"z` u" ,"z` ua :n" ,"z` ue :\i" ,"z` u@ :n" ,"z` uo" ,"s a" ,"s a :\i" ,"s a :n" ,"s A N" ,"s AU" ,"s 7" ,"s @ :n" ,"s @ N" ,"s` a" ,"s` a :\i" ,"s` a :n" ,"s` A N" ,"s` AU" ,"s` 7" ,"s` e :\i" ,"s` @ :n" ,"s` @ N" ,"s` i`" ,"s` @U" ,"s` u" ,"s` ua" ,"s` ua :\i" ,"s` ua :n" ,"s` uA N" ,"s` ue :\i" ,"s` u@ :n" ,"s` uo" ,"s i\\" ,"s U N" ,"s @U" ,"s u" ,"s ua :n" ,"s ue :\i" ,"s u@ :n" ,"s uo" ,"th a" ,"th a :\i" ,"th a :n" ,"th A N" ,"th AU" ,"th 7" ,"th @ N" ,"th i" ,"th iE :n" ,"th iAU" ,"th ie" ,"th i N" ,"th U N" ,"th @U" ,"th u" ,"th ua :n" ,"th ue :\i" ,"th u@ :n" ,"th uo" ,"w ua" ,"w ua :\i" ,"w ua :n" ,"w uA N" ,"w ue :\i" ,"w u@ :n" ,"w u@ N" ,"w uo" ,"u" ,"s\ i" ,"s\ ia" ,"s\ iE :n" ,"s\ iA N" ,"s\ iAU" ,"s\ ie" ,"s\ i :n" ,"s\ i N" ,"s\ iU N" ,"s\ i@U" ,"s\ y" ,"s\ y{ :n" ,"s\ yE" ,"s\ yE :n" ,"j ia" ,"j iE :n" ,"j iA N" ,"j iAU" ,"j ie" ,"i" ,"j i :n" ,"j i N" ,"j iAU" ,"j iU N" ,"j i@U" ,"y" ,"j y{ :n" ,"j yE" ,"j yE :n" ,"ts a" ,"ts a :\i" ,"ts a :n" ,"ts A N" ,"ts AU" ,"ts 7" ,"ts e :\i" ,"ts @ :n" ,"ts @ N" ,"ts` a" ,"ts` a :\i" ,"ts` a :n" ,"ts` A N" ,"ts` AU" ,"ts` 7" ,"ts` e :\i" ,"ts` @ :n" ,"ts` @ N" ,"ts` i`" ,"ts` U N" ,"ts` @U" ,"ts` u" ,"ts` ua" ,"ts` ua :\i" ,"ts` ua :n" ,"ts` uA N" ,"ts` ue :\i" ,"ts` u@ :n" ,"ts` uo" ,"ts i\\" ,"ts U N" ,"ts @U" ,"ts u" ,"ts ua :n" ,"ts ue :\i" ,"ts u@ :n" ,"ts uo"]

#创建一个音素数（phoneme_num）的空list
phoneme_num = []

#遍历音素list，让音素数（phoneme_num）对应上音素list
for ph in phoneme_li:
    ph_num = len(ph.split( ))
    phoneme_num.append(ph_num)

#将音素数(phoneme_num)加到df的DataFrame中
df["phoneme_num"] = phoneme_num

#将df这个DataFrame变成以音素数从小到大排序的DataFrame
df.sort_values("phoneme_num",inplace=True)
df
# Out:
#     pinyin     phoneme  phoneme_num
# 0        a           a            1
# 343     wu           u            1
# 217     ng           N            1
# 363     yi           i            1
# 234      o           o            1
# 235     ou          @U            1
# 79       e           7            1
# 369     yu           y            1
# 4       ao          AU            1
# 246   piao      ph iAU            2
# 206    mou        m @U            2
# 254    qia     ts\h ia            2
# 207     mu         m u            2
# 208     na         n a            2
# 212    nao        n AU            2
# 213     ne         n 7            2
# 253     qi      ts\h i            2
# 218     ni         n i            2
# 221   niao       n iAU            2
# 222    nie        n ie            2
# 225    niu       n i@U            2
# 227    nou        n @U            2
# 252     pu        ph u            2
# 228     nu         n u            2
# 229     nv         n y            2
# ...

# %%
#把DataFrame保存成excel文件
file_path = r'./pinyin-phoneme.xlsx'
writer = pd.ExcelWriter(file_path)
df.to_excel(writer, columns=['pinyin','phoneme','phoneme_num'], index=False,encoding='utf-8',sheet_name='Sheet')
writer.save()
